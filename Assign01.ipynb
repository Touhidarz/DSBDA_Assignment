# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("E:\TouhidDYP\DSBDA Lab/pizza_sales.csv")

# %%
df.describe()
# Out:
#            pizza_id      order_id      quantity    unit_price   total_price
# count  48620.000000  48620.000000  48620.000000  48620.000000  48620.000000
# mean   24310.500000  10701.479761      1.019622     16.494132     16.821474
# std    14035.529381   6180.119770      0.143077      3.621789      4.437398
# min        1.000000      1.000000      1.000000      9.750000      9.750000
# 25%    12155.750000   5337.000000      1.000000     12.750000     12.750000
# 50%    24310.500000  10682.500000      1.000000     16.500000     16.500000
# 75%    36465.250000  16100.000000      1.000000     20.250000     20.500000
# max    48620.000000  21350.000000      4.000000     35.950000     83.000000

# %%
df.isnull()
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date  order_time  \
# 0         False     False          False     False       False       False
# 1         False     False          False     False       False       False
# 2         False     False          False     False       False       False
# 3         False     False          False     False       False       False
# 4         False     False          False     False       False       False
# ...         ...       ...            ...       ...         ...         ...
# 48615     False     False          False     False       False       False
# 48616     False     False          False     False       False       False
# 48617     False     False          False     False       False       False
# 48618     False     False          False     False       False       False
# 48619     False     False          False     False       False       False
#
# ...

# %%
df.isnull().count()
# Out:
# pizza_id             48620
# order_id             48620
# pizza_name_id        48620
# quantity             48620
# order_date           48620
# order_time           48620
# unit_price           48620
# total_price          48620
# pizza_size           48620
# pizza_category       48620
# pizza_ingredients    48620
# pizza_name           48620
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  float64
#  1   order_id           48620 non-null  float64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  float64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: float64(5), object(7)
# memory usage: 4.5+ MB

# %%
df["pizza_name"]
# Out:
# 0        chicken
# 1        chicken
# 2        chicken
# 3        chicken
# 4        chicken
#           ...
# 48615    chicken
# 48616    chicken
# 48617    chicken
# 48618    chicken
# 48619    chicken
# Name: pizza_name, Length: 48620, dtype: object

# %%
df["unit_price"]
# Out:
# 0        13.25
# 1        16.00
# 2        18.50
# 3        20.75
# 4        16.00
#          ...
# 48615    16.75
# 48616    17.95
# 48617    12.00
# 48618    20.25
# 48619    12.75
# Name: unit_price, Length: 48620, dtype: float64

# %%
print(df)
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0           1.0       1.0     hawaiian_m       1.0    1/1/2015   11:38:36
# 1           2.0       2.0  classic_dlx_m       1.0    1/1/2015   11:57:40
# 2           3.0       2.0  five_cheese_l       1.0    1/1/2015   11:57:40
# 3           4.0       2.0    ital_supr_l       1.0    1/1/2015   11:57:40
# 4           5.0       2.0     mexicana_m       1.0    1/1/2015   11:57:40
# ...         ...       ...            ...       ...         ...        ...
# 48615   48616.0   21348.0  ckn_alfredo_m       1.0  31-12-2015   21:23:10
# 48616   48617.0   21348.0  four_cheese_l       1.0  31-12-2015   21:23:10
# 48617   48618.0   21348.0   napolitana_s       1.0  31-12-2015   21:23:10
# 48618   48619.0   21349.0     mexicana_l       1.0  31-12-2015   22:09:54
# 48619   48620.0   21350.0      bbq_ckn_s       1.0  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.head(10)
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0       1.0       1.0     hawaiian_m       1.0   1/1/2015   11:38:36
# 1       2.0       2.0  classic_dlx_m       1.0   1/1/2015   11:57:40
# 2       3.0       2.0  five_cheese_l       1.0   1/1/2015   11:57:40
# 3       4.0       2.0    ital_supr_l       1.0   1/1/2015   11:57:40
# 4       5.0       2.0     mexicana_m       1.0   1/1/2015   11:57:40
# 5       6.0       2.0     thai_ckn_l       1.0   1/1/2015   11:57:40
# 6       7.0       3.0    ital_supr_m       1.0   1/1/2015   12:12:28
# 7       8.0       3.0   prsc_argla_l       1.0   1/1/2015   12:12:28
# 8       9.0       4.0    ital_supr_m       1.0   1/1/2015   12:16:31
# 9      10.0       5.0    ital_supr_m       1.0   1/1/2015   12:21:30
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# ...

# %%
df.tail(10)
# Out:
#        pizza_id  order_id   pizza_name_id  quantity  order_date order_time  \
# 48610   48611.0   21346.0   soppressata_l       1.0  31-12-2015   20:51:07
# 48611   48612.0   21347.0       bbq_ckn_m       1.0  31-12-2015   21:14:37
# 48612   48613.0   21347.0     ital_supr_m       1.0  31-12-2015   21:14:37
# 48613   48614.0   21347.0  peppr_salami_s       1.0  31-12-2015   21:14:37
# 48614   48615.0   21347.0    southw_ckn_l       1.0  31-12-2015   21:14:37
# 48615   48616.0   21348.0   ckn_alfredo_m       1.0  31-12-2015   21:23:10
# 48616   48617.0   21348.0   four_cheese_l       1.0  31-12-2015   21:23:10
# 48617   48618.0   21348.0    napolitana_s       1.0  31-12-2015   21:23:10
# 48618   48619.0   21349.0      mexicana_l       1.0  31-12-2015   22:09:54
# 48619   48620.0   21350.0       bbq_ckn_s       1.0  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# 48610       20.75        20.75          L        Supreme
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48615    False
# 48616    False
# 48617    False
# 48618    False
# 48619    False
# Length: 48620, dtype: bool

# %%
print(df.dtypes)
# Out:
# pizza_id             float64
# order_id             float64
# pizza_name_id         object
# quantity             float64
# order_date            object
# order_time            object
# unit_price           float64
# total_price          float64
# pizza_size            object
# pizza_category        object
# pizza_ingredients     object
# pizza_name            object
# dtype: object

# %%
df['total_price'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48615    False
# 48616    False
# 48617    False
# 48618    False
# 48619    False
# Name: total_price, Length: 48620, dtype: bool

# %%
df['total_price'] = df['total_price'].astype(int)

# %%
print(df.dtypes)
# Out:
# pizza_id             float64
# order_id             float64
# pizza_name_id         object
# quantity             float64
# order_date            object
# order_time            object
# unit_price           float64
# total_price            int32
# pizza_size            object
# pizza_category        object
# pizza_ingredients     object
# pizza_name            object
# dtype: object

# %%
df['pizza_size'] = df['pizza_size'].astype(str)

# %%
print(df.dtypes)
# Out:
# pizza_id             float64
# order_id             float64
# pizza_name_id         object
# quantity             float64
# order_date            object
# order_time            object
# unit_price           float64
# total_price            int32
# pizza_size            object
# pizza_category        object
# pizza_ingredients     object
# pizza_name            object
# dtype: object

# %%
df['pizza_id'] = df['pizza_id'].astype(np.int32)

# %%
df['order_id'] = df['order_id'].astype(np.int32)

# %%
print(df)
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0             1         1     hawaiian_m       1.0    1/1/2015   11:38:36
# 1             2         2  classic_dlx_m       1.0    1/1/2015   11:57:40
# 2             3         2  five_cheese_l       1.0    1/1/2015   11:57:40
# 3             4         2    ital_supr_l       1.0    1/1/2015   11:57:40
# 4             5         2     mexicana_m       1.0    1/1/2015   11:57:40
# ...         ...       ...            ...       ...         ...        ...
# 48615     48616     21348  ckn_alfredo_m       1.0  31-12-2015   21:23:10
# 48616     48617     21348  four_cheese_l       1.0  31-12-2015   21:23:10
# 48617     48618     21348   napolitana_s       1.0  31-12-2015   21:23:10
# 48618     48619     21349     mexicana_l       1.0  31-12-2015   22:09:54
# 48619     48620     21350      bbq_ckn_s       1.0  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df["total_price"].min()
# Out:
# 9

# %%
df["total_price"].max()
# Out:
# 83

# %%
df['quantity'] = df['quantity'].astype(np.int32)

# %%
df.dtypes
# Out:
# pizza_id               int32
# order_id               int32
# pizza_name_id         object
# quantity               int32
# order_date            object
# order_time            object
# unit_price           float64
# total_price            int32
# pizza_size            object
# pizza_category        object
# pizza_ingredients     object
# pizza_name            object
# dtype: object

# %%
df.sort_values(by='pizza_size', ascending=True)
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 37229     37230     16437     hawaiian_l         1   3/10/2015   22:53:26
# 34642     34643     15291   napolitana_l         1   12/9/2015   21:08:36
# 15754     15755      6916  classic_dlx_l         1  26-04-2015   18:12:59
# 34643     34644     15291  pep_msh_pep_l         1   12/9/2015   21:08:36
# 34644     34645     15291   veggie_veg_l         1   12/9/2015   21:08:36
# ...         ...       ...            ...       ...         ...        ...
# 43040     43041     18919  the_greek_xxl         1  19-11-2015   16:58:26
# 19441     19442      8546  the_greek_xxl         1  23-05-2015   18:48:51
# 47489     47490     20866  the_greek_xxl         1  20-12-2015   19:16:20
# 17114     17115      7528  the_greek_xxl         1    7/5/2015   12:45:58
# 9844       9845      4307  the_greek_xxl         1  14-03-2015   13:19:35
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='%d/%m%Y', errors='coerce')

# %%
df.sort_values(by='pizza_size', ascending=True)
# Out:
#        pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 37229     37230     16437     hawaiian_l         1        NaT   22:53:26
# 34642     34643     15291   napolitana_l         1        NaT   21:08:36
# 15754     15755      6916  classic_dlx_l         1        NaT   18:12:59
# 34643     34644     15291  pep_msh_pep_l         1        NaT   21:08:36
# 34644     34645     15291   veggie_veg_l         1        NaT   21:08:36
# ...         ...       ...            ...       ...        ...        ...
# 43040     43041     18919  the_greek_xxl         1        NaT   16:58:26
# 19441     19442      8546  the_greek_xxl         1        NaT   18:48:51
# 47489     47490     20866  the_greek_xxl         1        NaT   19:16:20
# 17114     17115      7528  the_greek_xxl         1        NaT   12:45:58
# 9844       9845      4307  the_greek_xxl         1        NaT   13:19:35
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.sort_values(by='pizza_size', ascending=False)
# Out:
#        pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 20497     20498      9001  the_greek_xxl         1        NaT   18:31:11
# 3563       3564      1581  the_greek_xxl         1        NaT   16:28:38
# 47489     47490     20866  the_greek_xxl         1        NaT   19:16:20
# 35953     35954     15874  the_greek_xxl         1        NaT   20:26:26
# 36037     36038     15911  the_greek_xxl         1        NaT   16:34:56
# ...         ...       ...            ...       ...        ...        ...
# 32892     32893     14540     cali_ckn_l         1        NaT   14:48:21
# 32890     32891     14539  four_cheese_l         1        NaT   14:28:43
# 13967     13968      6121  classic_dlx_l         1        NaT   15:43:58
# 13968     13969      6122      bbq_ckn_l         1        NaT   16:20:07
# 24310     24311     10683    pepperoni_l         1        NaT   20:03:44
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.sort_values(by='quantity', ascending=True)
# Out:
#        pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0             1         1     hawaiian_m         1        NaT   11:38:36
# 32259     32260     14252     thai_ckn_l         1        NaT   15:31:15
# 32260     32261     14253    pepperoni_l         1        NaT   15:48:22
# 32261     32262     14254  spinach_fet_m         1        NaT   16:15:41
# 32262     32263     14255  classic_dlx_s         1        NaT   16:18:47
# ...         ...       ...            ...       ...        ...        ...
# 44157     44158     19411     big_meat_s         3        NaT   12:13:36
# 35627     35628     15728  ital_cpcllo_l         3        NaT   12:30:44
# 11976     11977      5264     big_meat_s         4        NaT   13:24:35
# 35496     35497     15674     cali_ckn_l         4        NaT   14:16:35
# 18875     18876      8286     big_meat_s         4        NaT   12:42:46
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df['quantity'].min()
# Out:
# 1

# %%
df['quantity'].max()
# Out:
# 4

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48615    False
# 48616    False
# 48617    False
# 48618    False
# 48619    False
# Length: 48620, dtype: bool

# %%
df.duplicated('pizza_name')
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 48615     True
# 48616     True
# 48617     True
# 48618     True
# 48619     True
# Length: 48620, dtype: bool

# %%
df.duplicated('pizza_id')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48615    False
# 48616    False
# 48617    False
# 48618    False
# 48619    False
# Length: 48620, dtype: bool

# %%
df.groupby('order_id').size()
# Out:
# order_id
# 1        1
# 2        5
# 3        2
# 4        1
# 5        1
#         ..
# 21346    4
# 21347    4
# 21348    3
# 21349    1
# 21350    1
# Length: 21350, dtype: int64
